# %%
import numpy as np
import skimage
import skimage.io
import seaborn as sns
import matplotlib.pyplot as plt
import glob
import pandas as pd
import shutil
from skimage import (
    data, restoration, util
)
import tifffile as tp

# %%
file_list = pd.Series(glob.glob('/home/giuseppe/devices/Delta_Tissue/IMC/Img_Denoised/*')).str.replace('Img_Denoised','split_channels_nohpf')+'/Carboplatin.tiff'
#file_list = glob.glob('/home/giuseppe/devices/Delta_Tissue/IMC/split_channels_nohpf/*/Carboplatin.tiff')
file_list = pd.DataFrame(file_list,columns = ['path'])
file_list['acquisition_ID'] = file_list.path.str.split('/').str[-2]
file_list['Leap_ID'] = file_list.acquisition_ID.str.split('_',n = 1).str[0].str.upper()
file_list['Leap_ID'] = file_list['Leap_ID'].str[:7]#leap_ID should be Leap123, anything more is stripped
biosamples_path = '~/devices/Delta_Tissue/IMC/IMC_data/ExtraDocs/processed_response.csv'
biosamples =pd.read_csv(biosamples_path)
file_list = file_list.merge(biosamples,left_on='Leap_ID',right_on= 'LEAP_ID').drop(['LEAP_ID'],axis = 1)#add metadata on patient

# %%
file_list
# Out:
#                                                   path acquisition_ID  \
# 0    /home/giuseppe/devices/Delta_Tissue/IMC/split_...      Leap081_8
# 1    /home/giuseppe/devices/Delta_Tissue/IMC/split_...      Leap081_1
# 2    /home/giuseppe/devices/Delta_Tissue/IMC/split_...     Leap081_12
# 3    /home/giuseppe/devices/Delta_Tissue/IMC/split_...      Leap081_3
# 4    /home/giuseppe/devices/Delta_Tissue/IMC/split_...      Leap081_6
# ..                                                 ...            ...
# 696  /home/giuseppe/devices/Delta_Tissue/IMC/split_...      Leap091_8
# 697  /home/giuseppe/devices/Delta_Tissue/IMC/split_...     Leap061_10
# 698  /home/giuseppe/devices/Delta_Tissue/IMC/split_...      Leap061_1
# 699  /home/giuseppe/devices/Delta_Tissue/IMC/split_...      Leap026_1
# 700  /home/giuseppe/devices/Delta_Tissue/IMC/split_...      Leap026_2
#
#      Leap_ID  SLIDE_NUMBER                      BIOBANK_ID  \
# 0    LEAP081          35.0             18000527-IncT FPE-2
# 1    LEAP081          35.0             18000527-IncT FPE-2
# 2    LEAP081          35.0             18000527-IncT FPE-2
# 3    LEAP081          35.0             18000527-IncT FPE-2
# 4    LEAP081          35.0             18000527-IncT FPE-2
# ..       ...           ...                             ...
# 696  LEAP091          39.0  21002291-FPE US (C)-1-FPEDiv-1
# 697  LEAP061          27.0             17050096-IncT FF-19
# 698  LEAP061          27.0             17050096-IncT FF-19
# 699  LEAP026          12.0  17035507-FPE US (C)-1-FPEDiv-1
# 700  LEAP026          12.0  17035507-FPE US (C)-1-FPEDiv-1
#
#     SAMPLE_TYPE_(CORE/RESECTION) FORMAT_(FFPE/FROZEN) FORCE_TRIAL?_(Y/N)  \
# 0                      RESECTION                 FFPE                NaN
# 1                      RESECTION                 FFPE                NaN
# 2                      RESECTION                 FFPE                NaN
# 3                      RESECTION                 FFPE                NaN
# 4                      RESECTION                 FFPE                NaN
# ..                           ...                  ...                ...
# 696                         CORE                 FFPE                NaN
# 697                    RESECTION               FROZEN                NaN
# 698                    RESECTION               FROZEN                NaN
# 699                         CORE                 FFPE                NaN
# 700                         CORE                 FFPE                NaN
#
#           DATE_SECTIONED H&E_NOTES  ST_NOTES       Response   COMMENTS
# 0    2023-02-06 00:00:00       NaN       NaN  Non-Responder  RESECTION
# 1    2023-02-06 00:00:00       NaN       NaN  Non-Responder  RESECTION
# 2    2023-02-06 00:00:00       NaN       NaN  Non-Responder  RESECTION
# 3    2023-02-06 00:00:00       NaN       NaN  Non-Responder  RESECTION
# 4    2023-02-06 00:00:00       NaN       NaN  Non-Responder  RESECTION
# ..                   ...       ...       ...            ...        ...
# 696  2023-03-06 00:00:00       NaN       NaN            pCR       CORE
# 697  2022-12-12 00:00:00       NaN       NaN  Non-Responder  RESECTION
# 698  2022-12-12 00:00:00       NaN       NaN  Non-Responder  RESECTION
# 699  2022-08-08 00:00:00       NaN       NaN  Non-Responder       CORE
# 700  2022-08-08 00:00:00       NaN       NaN  Non-Responder       CORE
#
# [701 rows x 13 columns]

# %%
skimage.__version__
# Out:
# '0.18.0'

# %%
for file in file_list.path:
    acquisition_id = file.split('/')[-2]
    #shutil.copy2(file,'/home/giuseppe/devices/Delta_Tissue/IMC/Img_Denoised/'+acquisition_id+'/Carboplatin.tiff')

# %%
#getting the 95% of core images. Also saving Carboplatin to 0
data = []
img_core = []
for file in file_list[file_list['SAMPLE_TYPE_(CORE/RESECTION)']=='CORE'].path:
    img = skimage.io.imread(file)
    img_core+=[img]
    data+=[np.quantile(img,q = 0.95)]
    output_file = file.replace('split_channels_nohpf','Img_Denoised')
    #tp.imwrite(output_file,np.zeros(img.shape).astype('float32'))
thr = np.quantile(data,q = 0.99)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_760980/466109079.py in ?()
#       4 #getting the 95% of core images. Also saving Carboplatin to 0
# ----> 5 data = []
#       6 img_core = []
#       7 for file in file_list[file_list['SAMPLE_TYPE_(CORE/RESECTION)']=='CORE'].path:
#       8     img = skimage.io.imread(file)
#
# ~/anaconda3/lib/python3.9/site-packages/skimage/io/_io.py in ?(fname, as_gray, plugin, **plugin_args)
#      49         if fname.lower().endswith(('.tiff', '.tif')):
#      50             plugin = 'tifffile'
#      51
#      52     with file_or_url_context(fname) as fname:
# ---> 53         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      54
#      55     if not hasattr(img, 'ndim'):
#      56         return img
#
# ~/anaconda3/lib/python3.9/site-packages/skimage/io/manage_plugins.py in ?(kind, *args, **kwargs)
#     201             func = [f for (p, f) in plugin_funcs if p == plugin][0]
#     202         except IndexError:
#     203             raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
#     204
# --> 205     return func(*args, **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/skimage/io/_plugins/tifffile_plugin.py in ?(fname, **kwargs)
#      70     """
#      71     if 'img_num' in kwargs:
#      72         kwargs['key'] = kwargs.pop('img_num')
#      73
# ---> 74     return tifffile_imread(fname, **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/tifffile/tifffile.py in ?(files, selection, aszarr, key, series, level, squeeze, maxworkers, buffersize, mode, name, offset, size, pattern, axesorder, categories, imread, sort, container, chunkshape, dtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, out, out_inplace, _multifile, _useframes, **kwargs)
#    1074
#    1075         if isinstance(files, str) or not isinstance(
#    1076             files, collections.abc.Sequence
#    1077         ):
# -> 1078             with TiffFile(
#    1079                 files,
#    1080                 mode=mode,
#    1081                 name=name,
#
# ~/anaconda3/lib/python3.9/site-packages/tifffile/tifffile.py in ?(self, file, mode, name, offset, size, omexml, _multifile, _useframes, _parent, **is_flags)
#    4072                 raise ValueError('invalid OME-XML')
#    4073             self._omexml = omexml
#    4074             self.is_ome = True
#    4075
# -> 4076         fh = FileHandle(file, mode=mode, name=name, offset=offset, size=size)
#    4077         self._fh = fh
#    4078         self._multifile = True if _multifile is None else bool(_multifile)
#    4079         self._files = {fh.name: self}
#
# ~/anaconda3/lib/python3.9/site-packages/tifffile/tifffile.py in ?(self, file, mode, name, offset, size)
#   14258         self._offset = -1 if offset is None else offset
#   14259         self._size = -1 if size is None else size
#   14260         self._close = True
#   14261         self._lock = NullContext()
# > 14262         self.open()
#   14263         assert self._fh is not None
#
# ~/anaconda3/lib/python3.9/site-packages/tifffile/tifffile.py in ?(self)
#   14277             if self._mode not in {'rb', 'r+b', 'wb', 'xb'}:
#   14278                 raise ValueError(f'invalid mode {self._mode}')
#   14279             self._file = os.path.realpath(self._file)
#   14280             self._dir, self._name = os.path.split(self._file)
# > 14281             self._fh = open(
#   14282                 self._file, self._mode, encoding=None
#   14283             )  # type: ignore
#   14284             self._close = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/giuseppe/devices/Delta_Tissue/IMC/split_channels_nohpf/Leap011_10/Carboplatin.tiff'

# %%
data_res = []
img_res=[]
for file in file_list[file_list['SAMPLE_TYPE_(CORE/RESECTION)']=='RESECTION'].path:
    #load the distribution of the image
    img = skimage.io.imread(file)
    img_res+=[img]
    q = np.quantile(img,q = 0.95)
    data_res +=[q]
    
max_data_res = max(data_res)
for img,file in zip(img_res,file_list[file_list['SAMPLE_TYPE_(CORE/RESECTION)']=='RESECTION'].path):
    img_float = skimage.exposure.rescale_intensity(img,in_range=(np.quantile(data,q = 0.95),max_data_res))
    if q>1.2:
        #if the image has a lot of signal, make it sharper
        img = skimage.exposure.rescale_intensity(skimage.exposure.equalize_hist(img_float))
    else:
        # in this case, exposure.equalize_hist tends to overcorrect dark region overamplifying noise. Use a more noise 
        img = skimage.exposure.rescale_intensity(skimage.exposure.equalize_adapthist(img_float))
    output_file = file.replace('split_channels_nohpf','Img_Denoised')
    #tp.imwrite(output_file,np.zeros(img.shape).astype('float32'))

thr = np.quantile(data_res,q = 0.95)

# %%
f,axs = plt.subplots(nrows=1,ncols=3,figsize = (20,20))
ind = 9
img = img_res[ind]
print(file_list[file_list['SAMPLE_TYPE_(CORE/RESECTION)']=='RESECTION'].acquisition_ID.iloc[ind])
img_float = skimage.exposure.rescale_intensity(img,in_range=(np.quantile(data,q = 0.95),max(data_res)))
axs[0].imshow(img_float,vmax = 1)
axs[1].imshow(skimage.exposure.equalize_adapthist(img_float),vmax = 1)
axs[2].imshow(skimage.exposure.equalize_hist(img_float),vmax = 1)

#background = restoration.rolling_ball(img_float,radius = 0.7)
#axs[1,0].imshow(skimage.exposure.equalize_hist(img_float-background),vmin = 0,vmax = 1)
# Out:
# Leap081_11

# %%
plt.imshow(skimage.exposure.rescale_intensity(skimage.exposure.equalize_hist(img_float)))
plt.colorbar()
plt.xlabel('$\\mu m$',fontsize = 14)
plt.ylabel('$\\mu m$',fontsize = 14)
#plt.savefig('Carboplatin.png')
# Out:
# Text(0, 0.5, '$\\mu m$')

# %%
skimage.exposure.equalize_hist(img_float)
# Out:
# array([[0.92741305, 0.62167007, 0.80091876, ..., 0.62167007, 0.62167007,
#         0.62167007],
#        [0.9731405 , 0.9309137 , 0.82634175, ..., 0.62167007, 0.62167007,
#         0.7081726 ],
#        [0.62167007, 0.62847066, 0.9282465 , ..., 0.62167007, 0.62167007,
#         0.62167007],
#        ...,
#        [0.719734  , 0.62167007, 0.62167007, ..., 0.62167007, 0.62167007,
#         0.91629744],
#        [0.62167007, 0.93639475, 0.7110979 , ..., 0.62167007, 0.7110979 ,
#         0.62167007],
#        [0.62167007, 0.62167007, 0.62167007, ..., 0.9042835 , 0.62167007,
#         0.62167007]], dtype=float32)

# %%
plt.hist([np.max(img) for img in img_list])
# Out:
# (array([181.,  12.,   4.,   4.,   4.,   0.,   0.,   2.,   0.,   2.]),
#  array([   5.81638861,  157.8323822 ,  309.84838867,  461.86437988,
#          613.88037109,  765.8963623 ,  917.91235352, 1069.92834473,
#         1221.94433594, 1373.96032715, 1525.97631836]),
#  <BarContainer object of 10 artists>)
