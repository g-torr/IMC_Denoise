# %%
from IMC_Denoise.IMC_Denoise_main.DeepSNiF_model import DeepSNiF_net, DeepSNiF_net_small
from keras.models import Input
from keras.utils.vis_utils import plot_model

import tensorflow as tf
input_ = Input (shape = (None, None, 1))

# %% [markdown]
# The code implements either a small or a normal network, here one can visualise both. I am going with the small network for the time being

# %%
normal =DeepSNiF_net(input = input_,names = 'a',loss_func = "I_divergence")
normal = tf.keras.Model(inputs=input_, outputs= normal)
small =DeepSNiF_net_small(input = input_,names = 'small',loss_func = "I_divergence")
small = tf.keras.Model(inputs=input_, outputs= small)

# %%
plot_model(normal)

# %%
print(normal.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv-Nodes1aResBlock1 (Conv2D)  (None, None, None, 6 576         input_1[0][0]
# __________________________________________________________________________________________________
# BN-Nodes1aResBlock1 (BatchNorma (None, None, None, 6 256         conv-Nodes1aResBlock1[0][0]
# __________________________________________________________________________________________________
# Relu-Nodes1aResBlock1 (Activati (None, None, None, 6 0           BN-Nodes1aResBlock1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
small.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv-smallBlock1 (Conv2D)       (None, None, None, 1 144         input_1[0][0]
# __________________________________________________________________________________________________
# BN-smallBlock1 (BatchNormalizat (None, None, None, 1 64          conv-smallBlock1[0][0]
# __________________________________________________________________________________________________
# Relu-smallBlock1 (Activation)   (None, None, None, 1 0           BN-smallBlock1[0][0]
# __________________________________________________________________________________________________
# ...
